# %%
! pip install collections-extended
! pip install langdetect
! pip install googletrans
! pip install seaborn
! pip install contractions
! pip install yake
! pip install rake_nltk
! pip install unidecode
! pip install googletrans==3.1.0a0
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# Collecting collections-extended
#   Downloading collections_extended-2.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: collections-extended
# Successfully installed collections-extended-2.0.2
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=5bbf7c16be7a29c1f247febb5359e9f02ab04fa1a9f26ed9a5bc4ed9236f9098
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans) (2023.11.17)
# Collecting hstspreload (from httpx==0.13.3->googletrans)
#   Downloading hstspreload-2024.1.5-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 17.0 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.9 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.8 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.9 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.7 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15715 sha256=ed063873f16986f6329c0bf07c4d31c52b7a7437b1d333279b22e98120b03bd7
#   Stored in directory: /root/.cache/pip/wheels/b3/81/ea/8b030407f8ebfc2f857814e086bb22ca2d4fea1a7be63652ab
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# Successfully installed chardet-3.0.4 googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.1.5 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.2 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from yake) (0.9.0)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.10/dist-packages (from yake) (8.1.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from yake) (1.23.5)
# Collecting segtok (from yake)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from yake) (3.2.1)
# Collecting jellyfish (from yake)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from segtok->yake) (2023.6.3)
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-1.0.3 segtok-1.5.11 yake-0.4.8
# Collecting rake_nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from rake_nltk) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.66.1)
# Installing collected packages: rake_nltk
# Successfully installed rake_nltk-1.0.6
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.11.17)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.1.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=f7d800c9ba695227cf432f61380fc0259e986f190299403f1d9aecfd76f9e14f
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# Successfully installed googletrans-3.1.0a0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from collections import Counter
l1 = [2,3,4,44,4,4,44,4,2,2,2,2]
count = Counter(l1)
# print(count)
# count.most_common(1)[0][0]
count.most_common(2)[1][0]
# Out:
# 4

# %%
# importing libraries
from langdetect import detect
from googletrans import Translator
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.util import ngrams
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
import contractions
import yake
from rake_nltk import Rake
from unidecode import unidecode
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer

# %%
data = pd.read_csv('dataset_es_train.csv')
data.head(2)
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0491108  product_es_0296024  reviewer_es_0999081      1
# 1  es_0869872  product_es_0922286  reviewer_es_0216771      1
#
#                                          review_body  \
# 0  Nada bueno se me fue ka pantalla en menos de 8...
# 1  Horrible, nos tuvimos que comprar otro porque ...
#
#                                 review_title language product_category
# 0                           television Nevir       es      electronics
# 1  Dinero tirado a la basura con esta compra       es      electronics

# %%
data.shape
# Out:
# (200000, 8)

# %%
sample = data.sample(1000)
sample.reset_index(drop=True,inplace=True)

# %%
sample
# Out:
#       review_id          product_id          reviewer_id  stars  \
# 0    es_0674126  product_es_0255052  reviewer_es_0123407      3
# 1    es_0856980  product_es_0218694  reviewer_es_0428216      3
# 2    es_0857878  product_es_0967342  reviewer_es_0543283      1
# 3    es_0227877  product_es_0023829  reviewer_es_0848941      1
# 4    es_0569743  product_es_0173339  reviewer_es_0100937      1
# ..          ...                 ...                  ...    ...
# 995  es_0010803  product_es_0002994  reviewer_es_0565098      5
# 996  es_0658434  product_es_0055336  reviewer_es_0768635      1
# 997  es_0983685  product_es_0682986  reviewer_es_0992413      1
# 998  es_0938172  product_es_0222624  reviewer_es_0255554      5
# 999  es_0257362  product_es_0095687  reviewer_es_0967022      3
#
#                                            review_body  \
# 0    Compre esta carcasa con el fin de utilizarla e...
# 1    La caja en si está bien, pero el vidrio vino s...
# 2                    Según he visto el envío es gratis
# 3    Aún no me ha llegado llevo esperando, me ponía...
# 4    Muy pesado y demasiado blando, dolor el cuello...
# ..                                                 ...
# 995  Preciosos colores, muy variados y de muy buena...
# 996  Necesitaría un poco mas de peso en la base por...
# 997  Lo tuve que devolver por que venia la caja ara...
# 998  Suena súper bien y fuerte, lo he estado usando...
# 999  Funciona perfectamente, pero le doy tres estre...
#
#                 review_title language  product_category
# 0                    Jessica       es            sports
# 1      Falla en los detalles       es           jewelry
# 2    Cargador de portátil hp       es           kitchen
# 3                    Llegada       es       electronics
# 4                     Leslie       es              home
# ..                       ...      ...               ...
# 995         Muy buena compra       es               toy
# 996             Mejorable...       es  home_improvement
# 997               Mal estado       es                pc
# 998              Durabilidad       es       electronics
# 999   funciona perfectamente       es          wireless
#
# [1000 rows x 8 columns]

# %%
df = sample[['review_body','stars']]
df
# Out:
#                                            review_body  stars
# 0    Compre esta carcasa con el fin de utilizarla e...      3
# 1    La caja en si está bien, pero el vidrio vino s...      3
# 2                    Según he visto el envío es gratis      1
# 3    Aún no me ha llegado llevo esperando, me ponía...      1
# 4    Muy pesado y demasiado blando, dolor el cuello...      1
# ..                                                 ...    ...
# 995  Preciosos colores, muy variados y de muy buena...      5
# 996  Necesitaría un poco mas de peso en la base por...      1
# 997  Lo tuve que devolver por que venia la caja ara...      1
# 998  Suena súper bien y fuerte, lo he estado usando...      5
# 999  Funciona perfectamente, pero le doy tres estre...      3
#
# [1000 rows x 2 columns]

# %%
# language detection
def lang_detect(data):
  lang = detect(data)
  return lang

# %%
print(df.review_body[0])
lang_detect(df.review_body[0])
# Out:
# Compre esta carcasa con el fin de utilizarla en mis actividades acuáticas pero no era compatible con el flotador oficial de GoPro, a pesar de ello hable con el servicio y se me devolvió la mitad del coste.
# 'es'

# %%
df['language'] = df.review_body.apply(lang_detect)
df
# Out:
#                                            review_body  stars language
# 0    Compre esta carcasa con el fin de utilizarla e...      3       es
# 1    La caja en si está bien, pero el vidrio vino s...      3       es
# 2                    Según he visto el envío es gratis      1       es
# 3    Aún no me ha llegado llevo esperando, me ponía...      1       es
# 4    Muy pesado y demasiado blando, dolor el cuello...      1       es
# ..                                                 ...    ...      ...
# 995  Preciosos colores, muy variados y de muy buena...      5       es
# 996  Necesitaría un poco mas de peso en la base por...      1       es
# 997  Lo tuve que devolver por que venia la caja ara...      1       es
# 998  Suena súper bien y fuerte, lo he estado usando...      5       es
# 999  Funciona perfectamente, pero le doy tres estre...      3       es
#
# [1000 rows x 3 columns]

# %%
df.language.unique()
# Out:
# array(['es', 'pt', 'en', 'ca', 'it'], dtype=object)

# %%
df.language.value_counts()
# Out:
# es    981
# pt     10
# en      7
# ca      1
# it      1
# Name: language, dtype: int64

# %%
# language translation
def lang_trans(data):
  translator = Translator()
  translated_text = translator.translate(data)
  return translated_text.text

# %%
print(df.review_body[0])
lang_trans(df.review_body[0])
# Out:
# Compre esta carcasa con el fin de utilizarla en mis actividades acuáticas pero no era compatible con el flotador oficial de GoPro, a pesar de ello hable con el servicio y se me devolvió la mitad del coste.
# 'I bought this housing in order to use it in my water activities but it was not compatible with the official GoPro float, despite this I spoke to the service and they refunded me half the cost.'

# %%
df['translated_reviews'] = df.review_body.apply(lang_trans)
df
# Out:
#                                            review_body  stars language  \
# 0    Compre esta carcasa con el fin de utilizarla e...      3       es
# 1    La caja en si está bien, pero el vidrio vino s...      3       es
# 2                    Según he visto el envío es gratis      1       es
# 3    Aún no me ha llegado llevo esperando, me ponía...      1       es
# 4    Muy pesado y demasiado blando, dolor el cuello...      1       es
# ..                                                 ...    ...      ...
# 995  Preciosos colores, muy variados y de muy buena...      5       es
# 996  Necesitaría un poco mas de peso en la base por...      1       es
# 997  Lo tuve que devolver por que venia la caja ara...      1       es
# 998  Suena súper bien y fuerte, lo he estado usando...      5       es
# 999  Funciona perfectamente, pero le doy tres estre...      3       es
#
#                                     translated_reviews
# 0    I bought this housing in order to use it in my...
# 1    The box itself is fine, but the glass came dir...
# 2                    As I have seen, shipping is free.
# 3    It hasn't arrived yet, I've been waiting, I th...
# 4    Very heavy and too soft, neck pain after sleep...
# ..                                                 ...
# 995  Beautiful colors, very varied and of very good...
# 996  It would need a little more weight on the base...
# 997  I had to return it because the box came scratc...
# 998  It sounds super good and strong, I have been u...
# 999  It works perfectly, but I give it three stars ...
#
# [1000 rows x 4 columns]

# %%
# ngrams
def ngram_extractor(data,ngram_range):
  tokens = word_tokenize(data)
  ngram = ngrams(tokens,ngram_range)
  ngram_list1 = []
  for ngram1 in ngram:
    ngram_list1.append(' '.join(ngram1))
  return ngram_list1

# %%
list_unigrams = df.translated_reviews.apply(lambda x : ngram_extractor(x,1))
list_unigrams
# Out:
# 0      [I, bought, this, housing, in, order, to, use,...
# 1      [The, box, itself, is, fine, ,, but, the, glas...
# 2          [As, I, have, seen, ,, shipping, is, free, .]
# 3      [It, has, n't, arrived, yet, ,, I, 've, been, ...
# 4      [Very, heavy, and, too, soft, ,, neck, pain, a...
#                              ...
# 995    [Beautiful, colors, ,, very, varied, and, of, ...
# 996    [It, would, need, a, little, more, weight, on,...
# 997    [I, had, to, return, it, because, the, box, ca...
# 998    [It, sounds, super, good, and, strong, ,, I, h...
# 999    [It, works, perfectly, ,, but, I, give, it, th...
# Name: translated_reviews, Length: 1000, dtype: object

# %%
final_unigram = []
for unigram in list_unigrams:
  final_unigram.extend(unigram)
cnt = Counter(final_unigram).most_common(25)
cnt
# Out:
# [('.', 1591),
#  ('the', 1482),
#  ('it', 1371),
#  (',', 1370),
#  ('I', 958),
#  ('and', 878),
#  ('is', 755),
#  ('to', 679),
#  ('a', 648),
#  ('for', 387),
#  ('not', 381),
#  ('It', 369),
#  ('that', 349),
#  ('of', 342),
#  ("n't", 327),
#  ('very', 326),
#  ('The', 299),
#  ('in', 285),
#  ('but', 285),
#  ('have', 285),
#  ('with', 258),
#  ('good', 231),
#  ('they', 213),
#  ('you', 190),
#  ('are', 180)]

# %%
# preprocessing
def expand_text(data):
  expanded_text = contractions.fix(data)
  return expanded_text

stopword_list = stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('nor')
stopword_list.remove('not')

def clean_data(data):
  tokens = word_tokenize(data)
  clean_text = [word.lower() for word in tokens if (word not in punctuation) and (word.lower() not in stopword_list) and (len(word)>2) and (word.isalpha())]
  return clean_text

# %%
clean_text = df.translated_reviews.apply(expand_text)
clean_text = clean_text.apply(clean_data)

# %%
clean_text
# Out:
# 0      [bought, housing, order, use, water, activitie...
# 1      [box, fine, glass, came, dirty, scratched, wel...
# 2                                 [seen, shipping, free]
# 3      [not, arrived, yet, waiting, thought, would, a...
# 4                    [heavy, soft, neck, pain, sleeping]
#                              ...
# 995    [beautiful, colors, varied, good, quality, ple...
# 996    [would, need, little, weight, base, support, w...
# 997    [return, box, came, scratched, raspberry, pins...
# 998    [sounds, super, good, strong, using, month, ma...
# 999    [works, perfectly, give, three, stars, request...
# Name: translated_reviews, Length: 1000, dtype: object

# %%
list_unigrams = clean_text.apply(lambda x : ngram_extractor(' '.join(x),1))
final_unigram = []
for unigram in list_unigrams:
  final_unigram.extend(unigram)
cnt = Counter(final_unigram).most_common(250)
cnt
# Out:
# [('not', 727),
#  ('good', 278),
#  ('quality', 133),
#  ('product', 125),
#  ('one', 124),
#  ('well', 109),
#  ('like', 109),
#  ('use', 85),
#  ('little', 85),
#  ('price', 79),
#  ('without', 75),
#  ('arrived', 73),
#  ('would', 70),
#  ('perfect', 69),
#  ('time', 65),
#  ('bad', 65),
#  ('bought', 64),
#  ('small', 59),
#  ('recommend', 58),
#  ('lot', 57),
#  ('size', 55),
#  ('much', 54),
#  ('see', 51),
#  ('two', 51),
#  ('even', 51),
#  ('perfectly', 49),
#  ('put', 49),
#  ('buy', 48),
#  ('great', 48),
#  ('work', 48),
#  ('since', 47),
#  ('everything', 46),
#  ('box', 45),
#  ('return', 45),
#  ('comes', 44),
#  ('also', 42),
#  ('case', 41),
#  ('give', 40),
#  ('used', 39),
#  ('light', 39),
#  ('works', 38),
#  ('come', 38),
#  ('purchase', 37),
#  ('fits', 37),
#  ('although', 36),
#  ('first', 35),
#  ('look', 35),
#  ('already', 35),
#  ('problem', 34),
#  ('received', 34),
#  ('quite', 34),
#  ('another', 34),
#  ('easy', 33),
#  ('thing', 33),
#  ('know', 32),
#  ('fine', 31),
#  ('came', 31),
#  ('could', 31),
#  ('plastic', 31),
#  ('comfortable', 30),
#  ('long', 29),
#  ('think', 29),
#  ('battery', 29),
#  ('make', 29),
#  ('gift', 28),
#  ('get', 28),
#  ('fit', 28),
#  ('expected', 28),
#  ('pretty', 28),
#  ('phone', 28),
#  ('seems', 27),
#  ('broken', 27),
#  ('day', 27),
#  ('yet', 26),
#  ('looks', 26),
#  ('truth', 26),
#  ('money', 26),
#  ('made', 26),
#  ('tried', 25),
#  ('months', 25),
#  ('photo', 25),
#  ('thought', 24),
#  ('better', 24),
#  ('amazon', 24),
#  ('order', 23),
#  ('happy', 23),
#  ('poor', 23),
#  ('anything', 23),
#  ('big', 22),
#  ('screen', 22),
#  ('enough', 22),
#  ('color', 21),
#  ('still', 21),
#  ('condition', 21),
#  ('cable', 21),
#  ('old', 21),
#  ('arrive', 20),
#  ('material', 20),
#  ('going', 20),
#  ('practical', 20),
#  ('quickly', 20),
#  ('want', 20),
#  ('liked', 20),
#  ('nothing', 19),
#  ('find', 19),
#  ('something', 19),
#  ('days', 19),
#  ('makes', 19),
#  ('less', 19),
#  ('say', 19),
#  ('charge', 19),
#  ('otherwise', 19),
#  ('watch', 19),
#  ('water', 18),
#  ('shipping', 18),
#  ('beautiful', 18),
#  ('cover', 18),
#  ('returned', 18),
#  ('way', 18),
#  ('package', 18),
#  ('expensive', 18),
#  ('worked', 18),
#  ('lasts', 18),
#  ('worth', 18),
#  ('design', 17),
#  ('ordered', 17),
#  ('touch', 17),
#  ('stars', 17),
#  ('able', 17),
#  ('difficult', 17),
#  ('end', 17),
#  ('book', 17),
#  ('home', 17),
#  ('delivery', 17),
#  ('best', 17),
#  ('correct', 17),
#  ('useful', 17),
#  ('completely', 17),
#  ('leaves', 17),
#  ('times', 17),
#  ('seller', 17),
#  ('many', 17),
#  ('right', 17),
#  ('problems', 17),
#  ('part', 17),
#  ('inside', 17),
#  ('paper', 17),
#  ('image', 17),
#  ('ones', 16),
#  ('large', 16),
#  ('packaging', 16),
#  ('fast', 16),
#  ('hours', 16),
#  ('ask', 16),
#  ('daughter', 16),
#  ('original', 16),
#  ('hair', 16),
#  ('recommended', 16),
#  ('open', 16),
#  ('short', 16),
#  ('sound', 16),
#  ('heavy', 15),
#  ('soft', 15),
#  ('last', 15),
#  ('gave', 15),
#  ('power', 15),
#  ('assemble', 15),
#  ('new', 15),
#  ('using', 15),
#  ('back', 15),
#  ('year', 15),
#  ('usb', 15),
#  ('brand', 15),
#  ('plus', 14),
#  ('loved', 14),
#  ('function', 14),
#  ('bit', 14),
#  ('need', 14),
#  ('nice', 14),
#  ('change', 14),
#  ('easily', 14),
#  ('photos', 14),
#  ('least', 14),
#  ('clean', 14),
#  ('button', 14),
#  ('glass', 13),
#  ('sent', 13),
#  ('rest', 13),
#  ('simple', 13),
#  ('take', 13),
#  ('every', 13),
#  ('piece', 13),
#  ('bag', 13),
#  ('far', 13),
#  ('model', 13),
#  ('wanted', 13),
#  ('hard', 13),
#  ('fabric', 13),
#  ('white', 13),
#  ('away', 13),
#  ('placed', 13),
#  ('longer', 13),
#  ('left', 13),
#  ('read', 12),
#  ('store', 12),
#  ('smaller', 12),
#  ('people', 12),
#  ('almost', 12),
#  ('looking', 12),
#  ('never', 12),
#  ('instructions', 12),
#  ('description', 12),
#  ('sometimes', 12),
#  ('support', 12),
#  ('feel', 12),
#  ('normal', 12),
#  ('things', 12),
#  ('loose', 12),
#  ('month', 12),
#  ('says', 12),
#  ('hold', 12),
#  ('space', 12),
#  ('weight', 12),
#  ('really', 12),
#  ('service', 11),
#  ('toy', 11),
#  ('point', 11),
#  ('said', 11),
#  ('pieces', 11),
#  ('resistant', 11),
#  ('remove', 11),
#  ('spanish', 11),
#  ('opinion', 11),
#  ('week', 11),
#  ('cut', 11),
#  ('may', 11),
#  ('years', 11),
#  ('place', 11),
#  ('buying', 11),
#  ('terrible', 11),
#  ('broke', 11),
#  ('connect', 11),
#  ('camera', 11),
#  ('disappointed', 11),
#  ('given', 11),
#  ('took', 11),
#  ('three', 11),
#  ('cheap', 11),
#  ('cool', 11),
#  ('noise', 11)]

# %%
list_bigrams = clean_text.apply(lambda x : ngram_extractor(' '.join(x),2))
final_bigram = []
for bigram in list_bigrams:
  final_bigram.extend(bigram)
cnt = Counter(final_bigram).most_common(25)
cnt
# Out:
# [('good quality', 45),
#  ('not like', 31),
#  ('not recommend', 29),
#  ('not work', 25),
#  ('not know', 22),
#  ('good product', 18),
#  ('not even', 18),
#  ('good price', 17),
#  ('poor quality', 16),
#  ('not bad', 16),
#  ('not used', 14),
#  ('would not', 14),
#  ('not arrived', 13),
#  ('fits perfectly', 13),
#  ('not give', 13),
#  ('not buy', 13),
#  ('not come', 12),
#  ('another one', 12),
#  ('without problem', 11),
#  ('not received', 11),
#  ('works well', 10),
#  ('not good', 10),
#  ('seems good', 9),
#  ('quality not', 9),
#  ('not arrive', 9)]

# %%
list_trigrams = clean_text.apply(lambda x : ngram_extractor(' '.join(x),3))
final_trigram = []
for trigram in list_trigrams:
  final_trigram.extend(trigram)
cnt = Counter(final_trigram).most_common(25)
cnt
# Out:
# [('good value money', 9),
#  ('would not buy', 7),
#  ('not arrived yet', 6),
#  ('not used yet', 6),
#  ('not like not', 5),
#  ('not fit well', 4),
#  ('buy another one', 4),
#  ('not give stars', 4),
#  ('not give opinion', 4),
#  ('give opinion not', 4),
#  ('opinion not arrived', 4),
#  ('box arrived broken', 3),
#  ('good quality not', 3),
#  ('not come spanish', 3),
#  ('not even know', 3),
#  ('not worth buying', 3),
#  ('not good quality', 3),
#  ('not like much', 3),
#  ('year old daughter', 3),
#  ('not look like', 3),
#  ('not cover entire', 3),
#  ('quality not good', 3),
#  ('battery lasts little', 3),
#  ('price not ask', 3),
#  ('seems good quality', 3)]

# %%
df.stars.unique()
# Out:
# array([3, 1, 5, 4, 2])

# %%
test = df[(df.stars.astype('int')<3)].reset_index(drop=True)
test
# Out:
#                                            review_body  stars language  \
# 0                    Según he visto el envío es gratis      1       es
# 1    Aún no me ha llegado llevo esperando, me ponía...      1       es
# 2    Muy pesado y demasiado blando, dolor el cuello...      1       es
# 3    Parece que va a ser un ordenador que puede usa...      1       es
# 4    No puedo opinar. Lo devuelvo ya que me enviaro...      1       es
# ..                                                 ...    ...      ...
# 383  Decepcionante. En la publicidad pone que duran...      1       es
# 384  Las hemos probado y no crecen tanto como creía...      2       es
# 385  No tiene nada para atarlos No es lo que pone e...      2       es
# 386  Necesitaría un poco mas de peso en la base por...      1       es
# 387  Lo tuve que devolver por que venia la caja ara...      1       es
#
#                                     translated_reviews
# 0                    As I have seen, shipping is free.
# 1    It hasn't arrived yet, I've been waiting, I th...
# 2    Very heavy and too soft, neck pain after sleep...
# 3    It seems that it is going to be a computer tha...
# 4    I can't comment. I am returning it since they ...
# ..                                                 ...
# 383  Disappointing. In the advertising it says that...
# 384  We have tried them and they do not grow as muc...
# 385  It doesn't have anything to tie them. It's not...
# 386  It would need a little more weight on the base...
# 387  I had to return it because the box came scratc...
#
# [388 rows x 4 columns]

# %%
clean_text = test.translated_reviews.apply(expand_text)
clean_text = clean_text.apply(clean_data)
list_trigrams = clean_text.apply(lambda x : ngram_extractor(' '.join(x),3))
final_trigram = []
for trigram in list_trigrams:
  final_trigram.extend(trigram)
cnt = Counter(final_trigram).most_common(25)
cnt
# Out:
# [('not arrived yet', 6),
#  ('would not buy', 6),
#  ('not like not', 5),
#  ('not fit well', 4),
#  ('buy another one', 4),
#  ('not give opinion', 4),
#  ('give opinion not', 4),
#  ('opinion not arrived', 4),
#  ('low quality product', 3),
#  ('arrived yet not', 3),
#  ('yet not give', 3),
#  ('not received product', 2),
#  ('not good quality', 2),
#  ('box arrived broken', 2),
#  ('waste time money', 2),
#  ('not like much', 2),
#  ('not arrive time', 2),
#  ('package never arrived', 2),
#  ('give one star', 2),
#  ('xiaomi redmi note', 2),
#  ('redmi note not', 2),
#  ('give two stars', 2),
#  ('not hear anything', 2),
#  ('not even work', 2),
#  ('not like anything', 2)]

# %%
"R1 R2"
Column
R1
R2

# %%
# wordcloud
def wordcloud(data,column):
  df_ = data[column].str.cat(sep=" ")
  wordcloud = WordCloud(width = 700, height=500,background_color='white').generate(df_)
  plt.figure(figsize=(10,16))
  plt.imshow(wordcloud)
  plt.axis('off')
  plt.show()

# %%
wordcloud(df,'translated_reviews')

# %%
for
print(end=" ")
