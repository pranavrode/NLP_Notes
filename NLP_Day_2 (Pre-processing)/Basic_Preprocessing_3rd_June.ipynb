# %%
# nltk 
# gensim
# spacy

# %%
# nltk.download(package_name)

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize, WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer, LancasterStemmer
from nltk.corpus import stopwords
from string import punctuation
import contractions
from unidecode import unidecode

# %%
text = """Ants are found everywhere in the world. They make their home in buildings, gardens
etc. They live in anthills. Ants are very hardworking insects. Throughout the summers they
collect food for the winter season. Whenever they find a sweet lying on the floor they stick
to the sweet and carry it to their home. Thus, in this way, they clean the floor.Ants are 
generally red and black in colour. They have two eyes and six legs. They are social insects. They
live in groups or colonies. Most ants are scavengers they collect whatever food they can find.
They are usually wingless but they develop wings when they reproduce. Their bites are quite 
painful."""

# %%
# sentence tokenization
sent = sent_tokenize(text)
sent
# Out:
# ['Ants are found everywhere in the world.',
#  'They make their home in buildings, gardens\netc.',
#  'They live in anthills.',
#  'Ants are very hardworking insects.',
#  'Throughout the summers they\ncollect food for the winter season.',
#  'Whenever they find a sweet lying on the floor they stick\nto the sweet and carry it to their home.',
#  'Thus, in this way, they clean the floor.Ants are \ngenerally red and black in colour.',
#  'They have two eyes and six legs.',
#  'They are social insects.',
#  'They\nlive in groups or colonies.',
#  'Most ants are scavengers they collect whatever food they can find.',
#  'They are usually wingless but they develop wings when they reproduce.',
#  'Their bites are quite \npainful.']

# %%
# Word tokenization
tokens = word_tokenize(text)
tokens
# Out:
# ['Ants',
#  'are',
#  'found',
#  'everywhere',
#  'in',
#  'the',
#  'world',
#  '.',
#  'They',
#  'make',
#  'their',
#  'home',
#  'in',
#  'buildings',
#  ',',
#  'gardens',
#  'etc',
#  '.',
#  'They',
#  'live',
#  'in',
#  'anthills',
#  '.',
#  'Ants',
#  'are',
#  'very',
#  'hardworking',
#  'insects',
#  '.',
#  'Throughout',
#  'the',
#  'summers',
#  'they',
#  'collect',
#  'food',
#  'for',
#  'the',
#  'winter',
#  'season',
#  '.',
#  'Whenever',
#  'they',
#  'find',
#  'a',
#  'sweet',
#  'lying',
#  'on',
#  'the',
#  'floor',
#  'they',
#  'stick',
#  'to',
#  'the',
#  'sweet',
#  'and',
#  'carry',
#  'it',
#  'to',
#  'their',
#  'home',
#  '.',
#  'Thus',
#  ',',
#  'in',
#  'this',
#  'way',
#  ',',
#  'they',
#  'clean',
#  'the',
#  'floor.Ants',
#  'are',
#  'generally',
#  'red',
#  'and',
#  'black',
#  'in',
#  'colour',
#  '.',
#  'They',
#  'have',
#  'two',
#  'eyes',
#  'and',
#  'six',
#  'legs',
#  '.',
#  'They',
#  'are',
#  'social',
#  'insects',
#  '.',
#  'They',
#  'live',
#  'in',
#  'groups',
#  'or',
#  'colonies',
#  '.',
#  'Most',
#  'ants',
#  'are',
#  'scavengers',
#  'they',
#  'collect',
#  'whatever',
#  'food',
#  'they',
#  'can',
#  'find',
#  '.',
#  'They',
#  'are',
#  'usually',
#  'wingless',
#  'but',
#  'they',
#  'develop',
#  'wings',
#  'when',
#  'they',
#  'reproduce',
#  '.',
#  'Their',
#  'bites',
#  'are',
#  'quite',
#  'painful',
#  '.']

# %%
# Whitespace tokenization
tokens1 = WhitespaceTokenizer().tokenize(text)
tokens1
# Out:
# ['Ants',
#  'are',
#  'found',
#  'everywhere',
#  'in',
#  'the',
#  'world.',
#  'They',
#  'make',
#  'their',
#  'home',
#  'in',
#  'buildings,',
#  'gardens',
#  'etc.',
#  'They',
#  'live',
#  'in',
#  'anthills.',
#  'Ants',
#  'are',
#  'very',
#  'hardworking',
#  'insects.',
#  'Throughout',
#  'the',
#  'summers',
#  'they',
#  'collect',
#  'food',
#  'for',
#  'the',
#  'winter',
#  'season.',
#  'Whenever',
#  'they',
#  'find',
#  'a',
#  'sweet',
#  'lying',
#  'on',
#  'the',
#  'floor',
#  'they',
#  'stick',
#  'to',
#  'the',
#  'sweet',
#  'and',
#  'carry',
#  'it',
#  'to',
#  'their',
#  'home.',
#  'Thus,',
#  'in',
#  'this',
#  'way,',
#  'they',
#  'clean',
#  'the',
#  'floor.Ants',
#  'are',
#  'generally',
#  'red',
#  'and',
#  'black',
#  'in',
#  'colour.',
#  'They',
#  'have',
#  'two',
#  'eyes',
#  'and',
#  'six',
#  'legs.',
#  'They',
#  'are',
#  'social',
#  'insects.',
#  'They',
#  'live',
#  'in',
#  'groups',
#  'or',
#  'colonies.',
#  'Most',
#  'ants',
#  'are',
#  'scavengers',
#  'they',
#  'collect',
#  'whatever',
#  'food',
#  'they',
#  'can',
#  'find.',
#  'They',
#  'are',
#  'usually',
#  'wingless',
#  'but',
#  'they',
#  'develop',
#  'wings',
#  'when',
#  'they',
#  'reproduce.',
#  'Their',
#  'bites',
#  'are',
#  'quite',
#  'painful.']

# %%
# normalization
lower_text = [word.lower() for word in tokens]
lower_text
# Out:
# ['ants',
#  'are',
#  'found',
#  'everywhere',
#  'in',
#  'the',
#  'world',
#  '.',
#  'they',
#  'make',
#  'their',
#  'home',
#  'in',
#  'buildings',
#  ',',
#  'gardens',
#  'etc',
#  '.',
#  'they',
#  'live',
#  'in',
#  'anthills',
#  '.',
#  'ants',
#  'are',
#  'very',
#  'hardworking',
#  'insects',
#  '.',
#  'throughout',
#  'the',
#  'summers',
#  'they',
#  'collect',
#  'food',
#  'for',
#  'the',
#  'winter',
#  'season',
#  '.',
#  'whenever',
#  'they',
#  'find',
#  'a',
#  'sweet',
#  'lying',
#  'on',
#  'the',
#  'floor',
#  'they',
#  'stick',
#  'to',
#  'the',
#  'sweet',
#  'and',
#  'carry',
#  'it',
#  'to',
#  'their',
#  'home',
#  '.',
#  'thus',
#  ',',
#  'in',
#  'this',
#  'way',
#  ',',
#  'they',
#  'clean',
#  'the',
#  'floor.ants',
#  'are',
#  'generally',
#  'red',
#  'and',
#  'black',
#  'in',
#  'colour',
#  '.',
#  'they',
#  'have',
#  'two',
#  'eyes',
#  'and',
#  'six',
#  'legs',
#  '.',
#  'they',
#  'are',
#  'social',
#  'insects',
#  '.',
#  'they',
#  'live',
#  'in',
#  'groups',
#  'or',
#  'colonies',
#  '.',
#  'most',
#  'ants',
#  'are',
#  'scavengers',
#  'they',
#  'collect',
#  'whatever',
#  'food',
#  'they',
#  'can',
#  'find',
#  '.',
#  'they',
#  'are',
#  'usually',
#  'wingless',
#  'but',
#  'they',
#  'develop',
#  'wings',
#  'when',
#  'they',
#  'reproduce',
#  '.',
#  'their',
#  'bites',
#  'are',
#  'quite',
#  'painful',
#  '.']

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# remove punctuations
text_without_punct = [word for word in lower_text if word not in punctuation]
text_without_punct
# Out:
# ['ants',
#  'are',
#  'found',
#  'everywhere',
#  'in',
#  'the',
#  'world',
#  'they',
#  'make',
#  'their',
#  'home',
#  'in',
#  'buildings',
#  'gardens',
#  'etc',
#  'they',
#  'live',
#  'in',
#  'anthills',
#  'ants',
#  'are',
#  'very',
#  'hardworking',
#  'insects',
#  'throughout',
#  'the',
#  'summers',
#  'they',
#  'collect',
#  'food',
#  'for',
#  'the',
#  'winter',
#  'season',
#  'whenever',
#  'they',
#  'find',
#  'a',
#  'sweet',
#  'lying',
#  'on',
#  'the',
#  'floor',
#  'they',
#  'stick',
#  'to',
#  'the',
#  'sweet',
#  'and',
#  'carry',
#  'it',
#  'to',
#  'their',
#  'home',
#  'thus',
#  'in',
#  'this',
#  'way',
#  'they',
#  'clean',
#  'the',
#  'floor.ants',
#  'are',
#  'generally',
#  'red',
#  'and',
#  'black',
#  'in',
#  'colour',
#  'they',
#  'have',
#  'two',
#  'eyes',
#  'and',
#  'six',
#  'legs',
#  'they',
#  'are',
#  'social',
#  'insects',
#  'they',
#  'live',
#  'in',
#  'groups',
#  'or',
#  'colonies',
#  'most',
#  'ants',
#  'are',
#  'scavengers',
#  'they',
#  'collect',
#  'whatever',
#  'food',
#  'they',
#  'can',
#  'find',
#  'they',
#  'are',
#  'usually',
#  'wingless',
#  'but',
#  'they',
#  'develop',
#  'wings',
#  'when',
#  'they',
#  'reproduce',
#  'their',
#  'bites',
#  'are',
#  'quite',
#  'painful']

# %%
stopword_list = stopwords.words("english")
stopword_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(stopword_list)
# Out:
# 179

# %%
# remove stopwords
text_without_stop = [word for word in text_without_punct if word not in stopword_list]
text_without_stop
# Out:
# ['ants',
#  'found',
#  'everywhere',
#  'world',
#  'make',
#  'home',
#  'buildings',
#  'gardens',
#  'etc',
#  'live',
#  'anthills',
#  'ants',
#  'hardworking',
#  'insects',
#  'throughout',
#  'summers',
#  'collect',
#  'food',
#  'winter',
#  'season',
#  'whenever',
#  'find',
#  'sweet',
#  'lying',
#  'floor',
#  'stick',
#  'sweet',
#  'carry',
#  'home',
#  'thus',
#  'way',
#  'clean',
#  'floor.ants',
#  'generally',
#  'red',
#  'black',
#  'colour',
#  'two',
#  'eyes',
#  'six',
#  'legs',
#  'social',
#  'insects',
#  'live',
#  'groups',
#  'colonies',
#  'ants',
#  'scavengers',
#  'collect',
#  'whatever',
#  'food',
#  'find',
#  'usually',
#  'wingless',
#  'develop',
#  'wings',
#  'reproduce',
#  'bites',
#  'quite',
#  'painful']

# %%
text_without_punct[:10]
# Out:
# ['ants',
#  'are',
#  'found',
#  'everywhere',
#  'in',
#  'the',
#  'world',
#  'they',
#  'make',
#  'their']

# %%
text_without_stop[:10]
# Out:
# ['ants',
#  'found',
#  'everywhere',
#  'world',
#  'make',
#  'home',
#  'buildings',
#  'gardens',
#  'etc',
#  'live']

# %%
# contraction mapping
text1 = "I didn't like the movie"
expanded_text = contractions.fix(text1)
expanded_text
# Out:
# 'I did not like the movie'

# %%
# contraction mapping
text1 = "I doesn't like the movie"
expanded_text = contractions.fix(text1)
expanded_text
# Out:
# 'I does not like the movie'

# %%
# contraction mapping
text1 = "I can't like the movie"
expanded_text = contractions.fix(text1)
expanded_text
# Out:
# 'I cannot like the movie'

# %%
{can't : can not} # replace

# %%
# stemming and lemmatization
stemming = LancasterStemmer()
lemmatizer = WordNetLemmatizer()
for word in text_without_stop:
    stemmed_word = stemming.stem(word)
    lemmatized_word = lemmatizer.lemmatize(word)
    print(f"Original_word >> {word}")
    print(f"stemmed_word >> {stemmed_word}")
    print(f"lemmatized_word >> {lemmatized_word}")
    print("*"*100)
# Out:
# Original_word >> ants
# stemmed_word >> ant
# lemmatized_word >> ant
# ****************************************************************************************************
# Original_word >> found
# stemmed_word >> found
# lemmatized_word >> found
# ****************************************************************************************************
# Original_word >> everywhere
# stemmed_word >> everywh
# lemmatized_word >> everywhere
# ****************************************************************************************************
# Original_word >> world
# stemmed_word >> world
# lemmatized_word >> world
# ****************************************************************************************************
# Original_word >> make
# stemmed_word >> mak
# lemmatized_word >> make
# ****************************************************************************************************
# Original_word >> home
# stemmed_word >> hom
# lemmatized_word >> home
# ****************************************************************************************************
# Original_word >> buildings
# stemmed_word >> build
# lemmatized_word >> building
# ****************************************************************************************************
# Original_word >> gardens
# stemmed_word >> gard
# lemmatized_word >> garden
# ****************************************************************************************************
# Original_word >> etc
# stemmed_word >> etc
# lemmatized_word >> etc
# ****************************************************************************************************
# Original_word >> live
# stemmed_word >> liv
# lemmatized_word >> live
# ****************************************************************************************************
# Original_word >> anthills
# stemmed_word >> anthil
# lemmatized_word >> anthill
# ****************************************************************************************************
# Original_word >> ants
# stemmed_word >> ant
# lemmatized_word >> ant
# ****************************************************************************************************
# Original_word >> hardworking
# stemmed_word >> hardwork
# lemmatized_word >> hardworking
# ****************************************************************************************************
# Original_word >> insects
# stemmed_word >> insect
# lemmatized_word >> insect
# ****************************************************************************************************
# Original_word >> throughout
# stemmed_word >> throughout
# lemmatized_word >> throughout
# ****************************************************************************************************
# Original_word >> summers
# stemmed_word >> sum
# lemmatized_word >> summer
# ****************************************************************************************************
# Original_word >> collect
# stemmed_word >> collect
# lemmatized_word >> collect
# ****************************************************************************************************
# Original_word >> food
# stemmed_word >> food
# lemmatized_word >> food
# ****************************************************************************************************
# Original_word >> winter
# stemmed_word >> wint
# lemmatized_word >> winter
# ****************************************************************************************************
# Original_word >> season
# stemmed_word >> season
# lemmatized_word >> season
# ****************************************************************************************************
# Original_word >> whenever
# stemmed_word >> whenev
# lemmatized_word >> whenever
# ****************************************************************************************************
# Original_word >> find
# stemmed_word >> find
# lemmatized_word >> find
# ****************************************************************************************************
# Original_word >> sweet
# stemmed_word >> sweet
# lemmatized_word >> sweet
# ****************************************************************************************************
# Original_word >> lying
# stemmed_word >> lying
# lemmatized_word >> lying
# ****************************************************************************************************
# Original_word >> floor
# stemmed_word >> flo
# lemmatized_word >> floor
# ****************************************************************************************************
# Original_word >> stick
# stemmed_word >> stick
# lemmatized_word >> stick
# ****************************************************************************************************
# Original_word >> sweet
# stemmed_word >> sweet
# lemmatized_word >> sweet
# ****************************************************************************************************
# Original_word >> carry
# stemmed_word >> carry
# lemmatized_word >> carry
# ****************************************************************************************************
# Original_word >> home
# stemmed_word >> hom
# lemmatized_word >> home
# ****************************************************************************************************
# Original_word >> thus
# stemmed_word >> thu
# lemmatized_word >> thus
# ****************************************************************************************************
# Original_word >> way
# stemmed_word >> way
# lemmatized_word >> way
# ****************************************************************************************************
# Original_word >> clean
# stemmed_word >> cle
# lemmatized_word >> clean
# ****************************************************************************************************
# Original_word >> floor.ants
# stemmed_word >> floor.ants
# lemmatized_word >> floor.ants
# ****************************************************************************************************
# Original_word >> generally
# stemmed_word >> gen
# lemmatized_word >> generally
# ****************************************************************************************************
# Original_word >> red
# stemmed_word >> red
# lemmatized_word >> red
# ****************************************************************************************************
# Original_word >> black
# stemmed_word >> black
# lemmatized_word >> black
# ****************************************************************************************************
# Original_word >> colour
# stemmed_word >> colo
# lemmatized_word >> colour
# ****************************************************************************************************
# Original_word >> two
# stemmed_word >> two
# lemmatized_word >> two
# ****************************************************************************************************
# Original_word >> eyes
# stemmed_word >> ey
# lemmatized_word >> eye
# ****************************************************************************************************
# Original_word >> six
# stemmed_word >> six
# lemmatized_word >> six
# ****************************************************************************************************
# Original_word >> legs
# stemmed_word >> leg
# lemmatized_word >> leg
# ****************************************************************************************************
# Original_word >> social
# stemmed_word >> soc
# lemmatized_word >> social
# ****************************************************************************************************
# Original_word >> insects
# stemmed_word >> insect
# lemmatized_word >> insect
# ****************************************************************************************************
# Original_word >> live
# stemmed_word >> liv
# lemmatized_word >> live
# ****************************************************************************************************
# Original_word >> groups
# stemmed_word >> group
# lemmatized_word >> group
# ****************************************************************************************************
# Original_word >> colonies
# stemmed_word >> colony
# lemmatized_word >> colony
# ****************************************************************************************************
# Original_word >> ants
# stemmed_word >> ant
# lemmatized_word >> ant
# ****************************************************************************************************
# Original_word >> scavengers
# stemmed_word >> scaveng
# lemmatized_word >> scavenger
# ****************************************************************************************************
# Original_word >> collect
# stemmed_word >> collect
# lemmatized_word >> collect
# ****************************************************************************************************
# Original_word >> whatever
# stemmed_word >> whatev
# lemmatized_word >> whatever
# ****************************************************************************************************
# Original_word >> food
# stemmed_word >> food
# lemmatized_word >> food
# ****************************************************************************************************
# Original_word >> find
# stemmed_word >> find
# lemmatized_word >> find
# ****************************************************************************************************
# Original_word >> usually
# stemmed_word >> us
# lemmatized_word >> usually
# ****************************************************************************************************
# Original_word >> wingless
# stemmed_word >> wingless
# lemmatized_word >> wingless
# ****************************************************************************************************
# Original_word >> develop
# stemmed_word >> develop
# lemmatized_word >> develop
# ****************************************************************************************************
# Original_word >> wings
# stemmed_word >> wing
# lemmatized_word >> wing
# ****************************************************************************************************
# Original_word >> reproduce
# stemmed_word >> reproduc
# lemmatized_word >> reproduce
# ****************************************************************************************************
# Original_word >> bites
# stemmed_word >> bit
# lemmatized_word >> bite
# ****************************************************************************************************
# Original_word >> quite
# stemmed_word >> quit
# lemmatized_word >> quite
# ****************************************************************************************************
# Original_word >> painful
# stemmed_word >> pain
# lemmatized_word >> painful
# ****************************************************************************************************

# %%
# handling accented characters
accented_characters = "Ô,ô,Ò,ò,Ñ,ñ,Ö,ö"
fixed_words = unidecode(accented_characters)
fixed_words
# Out:
# 'O,o,O,o,N,n,O,o'

# %%
from autocorrect import Speller
spell = Speller(lang='en')
print(spell('mussage'))
# Out:
# message

# %%
print(spell('survice'))
# Out:
# service

# %%
from textblob import TextBlob
a = 'mussage'
b = TextBlob(a)
print(b.correct())
# Out:
# message

# %%
from textblob import TextBlob
a = 'survice'
b = TextBlob(a)
print(b.correct())
# Out:
# service
